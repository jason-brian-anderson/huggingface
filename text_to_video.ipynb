# %% [markdown]
# <a href="https://colab.research.google.com/github/jason-brian-anderson/huggingface/blob/main/text_to_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install modelscope==1.4.2
# !pip install open_clip_torch
# !pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 92.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 KB 22.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 KB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 KB 44.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 45.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 23.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 73.4 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import snapshot_download

from modelscope.pipelines import pipeline
from modelscope.outputs import OutputKeys
import pathlib

model_dir = pathlib.Path('weights')
snapshot_download('damo-vilab/modelscope-damo-text-to-video-synthesis',
                   repo_type='model', local_dir=model_dir)

pipe = pipeline('text-to-video-synthesis', model_dir.as_posix())
test_text = {
        'text': 'Stocks close higher on Wednesday as tech names lead a turnaround, Dow adds 300 points: Live updates',
    }
output_video_path = pipe(test_text,)[OutputKeys.OUTPUT_VIDEO]
print('output_video_path:', output_video_path)
# Out:
# 2023-03-30 03:55:48,608 - modelscope - INFO - PyTorch version 1.13.1+cu116 Found.
# 2023-03-30 03:55:48,620 - modelscope - INFO - TensorFlow version 2.11.0 Found.
# 2023-03-30 03:55:48,622 - modelscope - INFO - Loading ast index from /root/.cache/modelscope/ast_indexer
# 2023-03-30 03:55:48,686 - modelscope - INFO - Loading done! Current index file version is 1.4.2, with md5 01ca9ab96d5bf988fdf20185a1f42279 and a total number of 842 components indexed
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# 2023-03-30 03:55:59,635 - modelscope - INFO - initiate model from weights
# 2023-03-30 03:55:59,636 - modelscope - INFO - initiate model from location weights.
# 2023-03-30 03:55:59,642 - modelscope - INFO - initialize model from weights
# 2023-03-30 03:57:47,375 - modelscope - WARNING - No preprocessor field found in cfg.
# 2023-03-30 03:57:47,385 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# ...

# %%
print('output_video_path:', output_video_path)
# Out:
# output_video_path: /tmp/tmp1cta_03m.mp4

# %%
# !ls -l /tmp/
# Out:
# total 2844
# -rw-r--r-- 1 root root    1183 Mar 30 03:30 dap_multiplexer.58e5e11c8f11.root.log.INFO.20230330-033055.90
# lrwxrwxrwx 1 root root      61 Mar 30 03:30 dap_multiplexer.INFO -> dap_multiplexer.58e5e11c8f11.root.log.INFO.20230330-033055.90
# srwxr-xr-x 1 root root       0 Mar 30 03:30 debugger_uafzq53bz
# drwx------ 2 root root    4096 Mar 30 03:30 initgoogle_syslog_dir.0
# -rw-r--r-- 1 root root 2261665 Mar 30 03:56 kernel_manager_proxy.58e5e11c8f11.root.log.INFO.20230330-033050.23
# lrwxrwxrwx 1 root root      66 Mar 30 03:30 kernel_manager_proxy.INFO -> kernel_manager_proxy.58e5e11c8f11.root.log.INFO.20230330-033050.23
# drwx------ 2 root root    4096 Mar 30 03:46 pyright-4162-IGCCsfcDcPF8
# drwx------ 2 root root    4096 Mar 30 03:46 pyright-4162-ymrk2tHUYLFY
# drwx------ 2 root root    4096 Mar 30 03:32 pyright-479-cPnel3dKU8du
# drwx------ 2 root root    4096 Mar 30 03:32 pyright-479-F1KzKvC14mWe
# drwx------ 2 root root    4096 Mar 30 03:32 pyright-625-jH3EBJteokXD
# ...
